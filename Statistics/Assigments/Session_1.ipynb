# %% [markdown]
# 1) List 5 daily actions you perform on apps like Instagram, Zomato, or Flipkart, and for each, identify whether the data generated is numerical or categorical.
# --> Instagram: Like post\reels - Numerical- Discrete - whole numbers(200likes,230)
#     Zomato: Rating of food - Numerical - Continuous - can have decimals (4.5,5,3.5)
#     Flipkart: Item selection - Categorical - Nominal - (clothes,electronics,makeup)
#     Instagram: Time Duration or spend - Numerical - Continous - decimals(1.5h,50,2.3)
#     Zomato: Food Items - Numerical- Discrete - whole numbers(4 items, 5,6)

# %% [markdown]
# 2) Given this sample data from a music app: ['Pop', 'Rock', 'Jazz', 'Hip-Hop', 'Pop', 'Rock', 'Jazz', 'Pop'], classify the type of data and explain your reasoning in 2-3 lines.
# --> It is Categorical data because it represent the different genres of music as it doesnot show any numerical data like (45,5,6,,7.8 etc)and apart from that it is nominal data as it doesnot showcase any ranking like (high,low,small,medium etc).

# %% [markdown]
# 3) Pick any one feature from an app you use (such as the number of likes on an Instagram post, or the rating of a restaurant on Zomato) and describe how statistics could help improve that feature for users.
# --> In instagram statistics help to analyze number of likes on each post as well as the highest viewed and liked reels available on the particular page. It can help the creator to know about what people like in content and how they can get more view and likes according to statistics.

# %% [markdown]
# 4) Suppose you are building a new playlist recommendation feature for a Spotify-like app. List 3 basic statistical terms (such as mean, median, mode, variance, etc.) that would be useful in analyzing user listening data, and explain each with a one-line example.
# --> Mean- Showcase average listening time and songs example : if users listen 20,40,30 songs in 3 days the average will be 30 songs.
#     Median - Showcase the middle value when the data is arranged in the order example: Data such as 10,20,30,40,50,60,70 minutes music listening time so the median will be 40
#     Mode - showcase the most used or frequently used number or category example: pop,rock,jazz,pop,pop,rock,jazz,jazz genres played the most recently so the mode will be POP.
