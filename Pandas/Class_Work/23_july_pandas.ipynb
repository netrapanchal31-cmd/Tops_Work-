# %%
import pandas as pd
import seaborn as sns

data_titanic = sns.load_dataset('titanic')

df = pd.DataFrame(data_titanic)

# %% [markdown]
# Find Missing Value

# %%
df.age.isnull().sum()
# Out:
# np.int64(177)

# %%
df.age.mean()

# %% [markdown]
# Count Values

# %%
df.sex.value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# Mean

# %%
df.age.mean()
# Out:
# np.float64(29.69911764705882)

# %% [markdown]
# Median

# %%
df.age.median()
# Out:
# np.float64(28.0)

# %% [markdown]
# Unique Genders In Data

# %%
df.sex.unique()
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %% [markdown]
# Not Unique Values in Data

# %%
df.sex.nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.sex.nunique()
#
# NameError: name 'df' is not defined

# %%
print(df.sex.value_counts().loc['male']/len(df)*100)

# %%
print(df.sex.value_counts().iloc[0]/len(df)*100)

# %%
print(df.deck.isnull().sum()/len(df)*100)

# %%
df['age'] = df['age'].fillna(df.age.median())

# %%
df.isnull().sum()

# %%
# Find Mode
df.embark_town.mode().iloc[0]

# %%
df.embark_town.value_counts()

# %%
df['embark_town'] = df.embark_town.fillna(df.embark_town.mode().iloc[0])

# %%
df.isnull().sum()

# %%
df

# %%
# See Tops 5 Data from DataFrame
df.head()

# %%
# See last 5 Data from DataFrame
df.tail()

# %%
df.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)

# %%
df

# %%
df.drop(columns=['embarked', 'class', 'who','adult_male','deck','alive','alone'],inplace=True)

# %%
df

# %%
df.reset_index(inplace=True)

# %%
df.isnull().sum().sum()
