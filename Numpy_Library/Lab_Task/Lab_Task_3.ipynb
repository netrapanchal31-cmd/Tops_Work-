# %%
import numpy as np
a= np.array([5,10,15])
b= np.array([1,2,3])
print("Addition: ", a+b)
print("Multiplication: ", a*b)
# Out:
# Addition:  [ 6 12 18]
# Multiplication:  [ 5 20 45]

# %%
arr= np.array([4,8,12,16])
print("Greater than 10: ",arr>10)
print("The numbers are: ", arr[arr>10])
# Out:
# Greater than 10:  [False False  True  True]
# The numbers are:  [12 16]
