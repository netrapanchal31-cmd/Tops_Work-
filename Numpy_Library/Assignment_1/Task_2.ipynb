# %%
import numpy as np 

ratings= np.array([[5,4,5,5,3],
                   [3,4,5,3,3],
                   [4,4,5,5,3],
                   [5,5,4,3,3]])
selected_rated=ratings[1:3]
print("Presenting 2nd and 3rd ratings: ",selected_rated)
# Out:
# Presenting 2nd and 3rd ratings:  [[3 4 5 3 3]
#  [4 4 5 5 3]]

# %%
steps=np.array([7500, 8200, 9000, 6800, 10500, 7900, 8500, 9500, 7200, 8800])
higest_steps=steps[steps>8000]
print("Steps greater than 8000:",higest_steps)
# Out:
# Steps greater than 8000: [ 8200  9000 10500  8500  9500  8800]

# %%
ipl_scores=np.array([180, 165, 210, 190, 175, 200, 220, 195])
select_scores=ipl_scores[[1,4,6]]
print("Scores from 2,5 and 7 matches:",select_scores)
# Out:
# Scores from 2,5 and 7 matches: [165 175 220]

# %%
price=np.array([500,1200,750,999,1500])
Discount_Price=price*0.90
print("Real Price:", price)
print("\nDiscounted Price:",Discount_Price)
# Out:
# Real Price: [ 500 1200  750  999 1500]
#
# Discounted Price: [ 450.  1080.   675.   899.1 1350. ]

# %%
ratings = np.array([5, -2, 3, 0, -1, 4, -5, 2])
ratings[ratings < 0] = 0
print("ratings:",ratings)
# Out:
# ratings: [5 0 3 0 0 4 0 2]
