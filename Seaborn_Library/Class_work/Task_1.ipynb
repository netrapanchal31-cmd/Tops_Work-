# %%
import seaborn as sns
sns.__version__
# Out:
# '0.13.2'

# %%
import numpy as np
sn=np.sin(np.arange(0,14,.5))
sn
# Out:
# array([ 0.        ,  0.47942554,  0.84147098,  0.99749499,  0.90929743,
#         0.59847214,  0.14112001, -0.35078323, -0.7568025 , -0.97753012,
#        -0.95892427, -0.70554033, -0.2794155 ,  0.21511999,  0.6569866 ,
#         0.93799998,  0.98935825,  0.79848711,  0.41211849, -0.07515112,
#        -0.54402111, -0.87969576, -0.99999021, -0.87545217, -0.53657292,
#        -0.0663219 ,  0.42016704,  0.80378443])

# %%
import matplotlib.pyplot as plt
plt.plot(sn)

plt.show()

# %%
plt.plot(sn)

plt.show()
sns.set_style('darkgrid')

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.set_style('whitegrid', {'axes.facecolor': 'cyan', 'axes.edgecolor': '0.1',
                            'figure.facecolor': 'orange',
                           'grid.color': '0.8',
                           'grid.linestyle': '--'})
plt.plot(sn)

plt.show()

# %%
sns.set_style('whitegrid')

# %%
plt.plot(sn)

plt.show()

# %%
sns.set_context('notebook')

# %%
plt.plot(sn)

plt.show()

# %%
sns.set_theme(style='darkgrid', context='notebook', palette='bright', font='sans-serif', font_scale=1.2)

# %%
plt.plot(sn, label='Sinewave')
plt.title('Sinewave')
plt.legend(loc='upper right',fontsize='xx-small')

plt.show()

# %%
plt.plot(sn)

plt.show()

# %%
import sweetviz as sv

# %%
import pandas as pd
survival_rate = titanic['survived'].mean() * 100

plt.figure(figsize=(4,5))
plt.bar(['Survival Rate'], [survival_rate], color='seagreen')
plt.ylim(0, 100)
plt.title("KPI: Overall Survival Rate")
plt.ylabel("Percentage (%)")

# Annotate the KPI value on top of the bar
plt.text(0, survival_rate + 2, f"{survival_rate:.1f}%", ha='center', fontsize=12, fontweight='bold')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 import pandas as pd
# ----> 2 survival_rate = titanic['survived'].mean() * 100
#       3
#       4 plt.figure(figsize=(4,5))
#       5 plt.bar(['Survival Rate'], [survival_rate], color='seagreen')
#
# NameError: name 'titanic' is not defined
